# %%
import os
import numpy as np
from collections import OrderedDict

# %%
from tflite import Model
data = open("./face_landmark.tflite", "rb").read()
model = Model.Model.GetRootAsModel(data, 0)

# %%
subgraph = model.Subgraphs(0)
subgraph.Name()
# Out:
# b'facemesh_facecontours_faceflag-blaze_shift30-2019_01_14-v0.tflite.no_meta'

# %%
def get_shape(tensor):
    return [tensor.Shape(i) for i in range(tensor.ShapeLength())]

# %%
for i in range(0, subgraph.TensorsLength()):
    tensor = subgraph.Tensors(i)
    print("%3d %30s %d %2d %s" % (i, tensor.Name(), tensor.Type(), tensor.Buffer(), 
                                  get_shape(subgraph.Tensors(i))))
# Out:
#   0                     b'input_1' 0  0 [1, 192, 192, 3]
#   1               b'conv2d/Kernel' 0  1 [16, 3, 3, 3]
#   2                 b'conv2d/Bias' 0  2 [16]
#   3                      b'conv2d' 0  0 [1, 96, 96, 16]
#   4               b'p_re_lu/Alpha' 0  3 [1, 1, 16]
#   5                     b'p_re_lu' 0  0 [1, 96, 96, 16]
#   6     b'depthwise_conv2d/Kernel' 0  4 [1, 3, 3, 16]
#   7       b'depthwise_conv2d/Bias' 0  5 [16]
#   8            b'depthwise_conv2d' 0  0 [1, 96, 96, 16]
#   9             b'conv2d_1/Kernel' 0  6 [16, 1, 1, 16]
#  10               b'conv2d_1/Bias' 0  7 [16]
#  11                    b'conv2d_1' 0  0 [1, 96, 96, 16]
#  12                         b'add' 0  0 [1, 96, 96, 16]
#  13             b'p_re_lu_1/Alpha' 0  8 [1, 1, 16]
#  14                   b'p_re_lu_1' 0  0 [1, 96, 96, 16]
#  15   b'depthwise_conv2d_1/Kernel' 0  9 [1, 3, 3, 16]
#  16     b'depthwise_conv2d_1/Bias' 0 10 [16]
#  17          b'depthwise_conv2d_1' 0  0 [1, 96, 96, 16]
#  18             b'conv2d_2/Kernel' 0 11 [16, 1, 1, 16]
#  19               b'conv2d_2/Bias' 0 12 [16]
#  20                    b'conv2d_2' 0  0 [1, 96, 96, 16]
#  21                       b'add_1' 0  0 [1, 96, 96, 16]
#  22             b'p_re_lu_2/Alpha' 0 13 [1, 1, 16]
#  23                   b'p_re_lu_2' 0  0 [1, 96, 96, 16]
#  24   b'depthwise_conv2d_2/Kernel' 0 14 [1, 3, 3, 16]
#  25     b'depthwise_conv2d_2/Bias' 0 15 [16]
#  26          b'depthwise_conv2d_2' 0  0 [1, 48, 48, 16]
#  27               b'max_pooling2d' 0  0 [1, 48, 48, 16]
#  28             b'conv2d_3/Kernel' 0 16 [32, 1, 1, 16]
#  29               b'conv2d_3/Bias' 0 17 [32]
#  30                    b'conv2d_3' 0  0 [1, 48, 48, 32]
#  31    b'channel_padding/Paddings' 2 18 [4, 2]
#  32             b'channel_padding' 0  0 [1, 48, 48, 32]
#  33                       b'add_2' 0  0 [1, 48, 48, 32]
#  34             b'p_re_lu_3/Alpha' 0 19 [1, 1, 32]
#  35                   b'p_re_lu_3' 0  0 [1, 48, 48, 32]
#  36   b'depthwise_conv2d_3/Kernel' 0 20 [1, 3, 3, 32]
#  37     b'depthwise_conv2d_3/Bias' 0 21 [32]
#  38          b'depthwise_conv2d_3' 0  0 [1, 48, 48, 32]
#  39             b'conv2d_4/Kernel' 0 22 [32, 1, 1, 32]
#  40               b'conv2d_4/Bias' 0 23 [32]
#  41                    b'conv2d_4' 0  0 [1, 48, 48, 32]
#  42                       b'add_3' 0  0 [1, 48, 48, 32]
#  43             b'p_re_lu_4/Alpha' 0 24 [1, 1, 32]
#  44                   b'p_re_lu_4' 0  0 [1, 48, 48, 32]
#  45   b'depthwise_conv2d_4/Kernel' 0 25 [1, 3, 3, 32]
#  46     b'depthwise_conv2d_4/Bias' 0 26 [32]
#  47          b'depthwise_conv2d_4' 0  0 [1, 48, 48, 32]
#  48             b'conv2d_5/Kernel' 0 27 [32, 1, 1, 32]
#  49               b'conv2d_5/Bias' 0 28 [32]
#  50                    b'conv2d_5' 0  0 [1, 48, 48, 32]
#  51                       b'add_4' 0  0 [1, 48, 48, 32]
#  52             b'p_re_lu_5/Alpha' 0 29 [1, 1, 32]
#  53                   b'p_re_lu_5' 0  0 [1, 48, 48, 32]
#  54   b'depthwise_conv2d_5/Kernel' 0 30 [1, 3, 3, 32]
#  55     b'depthwise_conv2d_5/Bias' 0 31 [32]
#  56          b'depthwise_conv2d_5' 0  0 [1, 24, 24, 32]
#  57             b'max_pooling2d_1' 0  0 [1, 24, 24, 32]
#  58             b'conv2d_6/Kernel' 0 32 [64, 1, 1, 32]
#  59               b'conv2d_6/Bias' 0 33 [64]
#  60                    b'conv2d_6' 0  0 [1, 24, 24, 64]
#  61  b'channel_padding_1/Paddings' 2 34 [4, 2]
#  62           b'channel_padding_1' 0  0 [1, 24, 24, 64]
#  63                       b'add_5' 0  0 [1, 24, 24, 64]
#  64             b'p_re_lu_6/Alpha' 0 35 [1, 1, 64]
#  65                   b'p_re_lu_6' 0  0 [1, 24, 24, 64]
#  66   b'depthwise_conv2d_6/Kernel' 0 36 [1, 3, 3, 64]
#  67     b'depthwise_conv2d_6/Bias' 0 37 [64]
#  68          b'depthwise_conv2d_6' 0  0 [1, 24, 24, 64]
#  69             b'conv2d_7/Kernel' 0 38 [64, 1, 1, 64]
#  70               b'conv2d_7/Bias' 0 39 [64]
#  71                    b'conv2d_7' 0  0 [1, 24, 24, 64]
#  72                       b'add_6' 0  0 [1, 24, 24, 64]
#  73             b'p_re_lu_7/Alpha' 0 40 [1, 1, 64]
#  74                   b'p_re_lu_7' 0  0 [1, 24, 24, 64]
#  75   b'depthwise_conv2d_7/Kernel' 0 41 [1, 3, 3, 64]
#  76     b'depthwise_conv2d_7/Bias' 0 42 [64]
#  77          b'depthwise_conv2d_7' 0  0 [1, 24, 24, 64]
#  78             b'conv2d_8/Kernel' 0 43 [64, 1, 1, 64]
#  79               b'conv2d_8/Bias' 0 44 [64]
#  80                    b'conv2d_8' 0  0 [1, 24, 24, 64]
#  81                       b'add_7' 0  0 [1, 24, 24, 64]
#  82             b'p_re_lu_8/Alpha' 0 45 [1, 1, 64]
#  83                   b'p_re_lu_8' 0  0 [1, 24, 24, 64]
#  84   b'depthwise_conv2d_8/Kernel' 0 46 [1, 3, 3, 64]
#  85     b'depthwise_conv2d_8/Bias' 0 47 [64]
#  86          b'depthwise_conv2d_8' 0  0 [1, 12, 12, 64]
#  87             b'max_pooling2d_2' 0  0 [1, 12, 12, 64]
#  88             b'conv2d_9/Kernel' 0 48 [128, 1, 1, 64]
#  89               b'conv2d_9/Bias' 0 49 [128]
#  90                    b'conv2d_9' 0  0 [1, 12, 12, 128]
#  91  b'channel_padding_2/Paddings' 2 50 [4, 2]
#  92           b'channel_padding_2' 0  0 [1, 12, 12, 128]
#  93                       b'add_8' 0  0 [1, 12, 12, 128]
#  94             b'p_re_lu_9/Alpha' 0 51 [1, 1, 128]
#  95                   b'p_re_lu_9' 0  0 [1, 12, 12, 128]
#  96   b'depthwise_conv2d_9/Kernel' 0 52 [1, 3, 3, 128]
#  97     b'depthwise_conv2d_9/Bias' 0 53 [128]
#  98          b'depthwise_conv2d_9' 0  0 [1, 12, 12, 128]
#  99            b'conv2d_10/Kernel' 0 54 [128, 1, 1, 128]
# 100              b'conv2d_10/Bias' 0 55 [128]
# 101                   b'conv2d_10' 0  0 [1, 12, 12, 128]
# 102                       b'add_9' 0  0 [1, 12, 12, 128]
# 103            b'p_re_lu_10/Alpha' 0 56 [1, 1, 128]
# 104                  b'p_re_lu_10' 0  0 [1, 12, 12, 128]
# 105  b'depthwise_conv2d_10/Kernel' 0 57 [1, 3, 3, 128]
# 106    b'depthwise_conv2d_10/Bias' 0 58 [128]
# 107         b'depthwise_conv2d_10' 0  0 [1, 12, 12, 128]
# 108            b'conv2d_11/Kernel' 0 59 [128, 1, 1, 128]
# 109              b'conv2d_11/Bias' 0 60 [128]
# 110                   b'conv2d_11' 0  0 [1, 12, 12, 128]
# 111                      b'add_10' 0  0 [1, 12, 12, 128]
# 112            b'p_re_lu_11/Alpha' 0 61 [1, 1, 128]
# 113                  b'p_re_lu_11' 0  0 [1, 12, 12, 128]
# 114  b'depthwise_conv2d_11/Kernel' 0 62 [1, 3, 3, 128]
# 115    b'depthwise_conv2d_11/Bias' 0 63 [128]
# 116         b'depthwise_conv2d_11' 0  0 [1, 6, 6, 128]
# 117            b'conv2d_12/Kernel' 0 64 [128, 1, 1, 128]
# 118              b'conv2d_12/Bias' 0 65 [128]
# 119                   b'conv2d_12' 0  0 [1, 6, 6, 128]
# 120             b'max_pooling2d_3' 0  0 [1, 6, 6, 128]
# 121                      b'add_11' 0  0 [1, 6, 6, 128]
# 122            b'p_re_lu_12/Alpha' 0 66 [1, 1, 128]
# 123                  b'p_re_lu_12' 0  0 [1, 6, 6, 128]
# 124  b'depthwise_conv2d_12/Kernel' 0 67 [1, 3, 3, 128]
# 125    b'depthwise_conv2d_12/Bias' 0 68 [128]
# 126         b'depthwise_conv2d_12' 0  0 [1, 6, 6, 128]
# 127            b'conv2d_13/Kernel' 0 69 [128, 1, 1, 128]
# 128              b'conv2d_13/Bias' 0 70 [128]
# 129                   b'conv2d_13' 0  0 [1, 6, 6, 128]
# 130                      b'add_12' 0  0 [1, 6, 6, 128]
# 131            b'p_re_lu_13/Alpha' 0 71 [1, 1, 128]
# 132                  b'p_re_lu_13' 0  0 [1, 6, 6, 128]
# 133  b'depthwise_conv2d_13/Kernel' 0 72 [1, 3, 3, 128]
# 134    b'depthwise_conv2d_13/Bias' 0 73 [128]
# 135         b'depthwise_conv2d_13' 0  0 [1, 6, 6, 128]
# 136            b'conv2d_14/Kernel' 0 74 [128, 1, 1, 128]
# 137              b'conv2d_14/Bias' 0 75 [128]
# 138                   b'conv2d_14' 0  0 [1, 6, 6, 128]
# 139                      b'add_13' 0  0 [1, 6, 6, 128]
# 140            b'p_re_lu_14/Alpha' 0 76 [1, 1, 128]
# 141                  b'p_re_lu_14' 0  0 [1, 6, 6, 128]
# 142  b'depthwise_conv2d_14/Kernel' 0 77 [1, 3, 3, 128]
# 143    b'depthwise_conv2d_14/Bias' 0 78 [128]
# 144         b'depthwise_conv2d_14' 0  0 [1, 3, 3, 128]
# 145            b'conv2d_15/Kernel' 0 79 [128, 1, 1, 128]
# 146              b'conv2d_15/Bias' 0 80 [128]
# 147                   b'conv2d_15' 0  0 [1, 3, 3, 128]
# 148             b'max_pooling2d_4' 0  0 [1, 3, 3, 128]
# 149                      b'add_14' 0  0 [1, 3, 3, 128]
# 150            b'p_re_lu_15/Alpha' 0 81 [1, 1, 128]
# 151                  b'p_re_lu_15' 0  0 [1, 3, 3, 128]
# 152  b'depthwise_conv2d_15/Kernel' 0 82 [1, 3, 3, 128]
# 153    b'depthwise_conv2d_15/Bias' 0 83 [128]
# 154         b'depthwise_conv2d_15' 0  0 [1, 3, 3, 128]
# 155            b'conv2d_16/Kernel' 0 84 [128, 1, 1, 128]
# 156              b'conv2d_16/Bias' 0 85 [128]
# 157                   b'conv2d_16' 0  0 [1, 3, 3, 128]
# 158                      b'add_15' 0  0 [1, 3, 3, 128]
# 159            b'p_re_lu_16/Alpha' 0 86 [1, 1, 128]
# 160                  b'p_re_lu_16' 0  0 [1, 3, 3, 128]
# 161  b'depthwise_conv2d_22/Kernel' 0 87 [1, 3, 3, 128]
# 162    b'depthwise_conv2d_22/Bias' 0 88 [128]
# 163         b'depthwise_conv2d_22' 0  0 [1, 3, 3, 128]
# 164  b'depthwise_conv2d_16/Kernel' 0 89 [1, 3, 3, 128]
# 165    b'depthwise_conv2d_16/Bias' 0 90 [128]
# 166         b'depthwise_conv2d_16' 0  0 [1, 3, 3, 128]
# 167            b'conv2d_27/Kernel' 0 91 [128, 1, 1, 128]
# 168              b'conv2d_27/Bias' 0 92 [128]
# 169                   b'conv2d_27' 0  0 [1, 3, 3, 128]
# 170            b'conv2d_17/Kernel' 0 93 [128, 1, 1, 128]
# 171              b'conv2d_17/Bias' 0 94 [128]
# 172                   b'conv2d_17' 0  0 [1, 3, 3, 128]
# 173             b'max_pooling2d_6' 0  0 [1, 3, 3, 128]
# 174                      b'add_22' 0  0 [1, 3, 3, 128]
# 175                      b'add_16' 0  0 [1, 3, 3, 128]
# 176            b'p_re_lu_25/Alpha' 0 95 [1, 1, 128]
# 177                  b'p_re_lu_25' 0  0 [1, 3, 3, 128]
# 178            b'p_re_lu_17/Alpha' 0 96 [1, 1, 128]
# 179                  b'p_re_lu_17' 0  0 [1, 3, 3, 128]
# 180            b'conv2d_28/Kernel' 0 97 [32, 1, 1, 128]
# 181              b'conv2d_28/Bias' 0 98 [32]
# 182                   b'conv2d_28' 0  0 [1, 3, 3, 32]
# 183            b'conv2d_18/Kernel' 0 99 [32, 1, 1, 128]
# 184              b'conv2d_18/Bias' 0 100 [32]
# 185                   b'conv2d_18' 0  0 [1, 3, 3, 32]
# 186            b'p_re_lu_26/Alpha' 0 101 [1, 1, 32]
# 187                  b'p_re_lu_26' 0  0 [1, 3, 3, 32]
# 188            b'p_re_lu_18/Alpha' 0 102 [1, 1, 32]
# 189                  b'p_re_lu_18' 0  0 [1, 3, 3, 32]
# 190  b'depthwise_conv2d_23/Kernel' 0 103 [1, 3, 3, 32]
# 191    b'depthwise_conv2d_23/Bias' 0 104 [32]
# 192         b'depthwise_conv2d_23' 0  0 [1, 3, 3, 32]
# 193  b'depthwise_conv2d_17/Kernel' 0 105 [1, 3, 3, 32]
# 194    b'depthwise_conv2d_17/Bias' 0 106 [32]
# 195         b'depthwise_conv2d_17' 0  0 [1, 3, 3, 32]
# 196            b'conv2d_29/Kernel' 0 107 [32, 1, 1, 32]
# 197              b'conv2d_29/Bias' 0 108 [32]
# 198                   b'conv2d_29' 0  0 [1, 3, 3, 32]
# 199            b'conv2d_19/Kernel' 0 109 [32, 1, 1, 32]
# 200              b'conv2d_19/Bias' 0 110 [32]
# 201                   b'conv2d_19' 0  0 [1, 3, 3, 32]
# 202                      b'add_23' 0  0 [1, 3, 3, 32]
# 203                      b'add_17' 0  0 [1, 3, 3, 32]
# 204            b'p_re_lu_27/Alpha' 0 111 [1, 1, 32]
# 205                  b'p_re_lu_27' 0  0 [1, 3, 3, 32]
# 206            b'p_re_lu_19/Alpha' 0 112 [1, 1, 32]
# 207                  b'p_re_lu_19' 0  0 [1, 3, 3, 32]
# 208            b'conv2d_30/Kernel' 0 113 [1, 3, 3, 32]
# 209              b'conv2d_30/Bias' 0 114 [1]
# 210                   b'conv2d_30' 0  0 [1, 1, 1, 1]
# 211            b'conv2d_20/Kernel' 0 115 [1404, 3, 3, 32]
# 212              b'conv2d_20/Bias' 0 116 [1404]
# 213                   b'conv2d_20' 0  0 [1, 1, 1, 1404]

# %%
tensor_dict = {(subgraph.Tensors(i).Name().decode("utf8")): i 
               for i in range(subgraph.TensorsLength())}

# %%
tensor_dict
# Out:
# {'input_1': 0,
#  'conv2d/Kernel': 1,
#  'conv2d/Bias': 2,
#  'conv2d': 3,
#  'p_re_lu/Alpha': 4,
#  'p_re_lu': 5,
#  'depthwise_conv2d/Kernel': 6,
#  'depthwise_conv2d/Bias': 7,
#  'depthwise_conv2d': 8,
#  'conv2d_1/Kernel': 9,
#  'conv2d_1/Bias': 10,
#  'conv2d_1': 11,
#  'add': 12,
#  'p_re_lu_1/Alpha': 13,
#  'p_re_lu_1': 14,
#  'depthwise_conv2d_1/Kernel': 15,
#  'depthwise_conv2d_1/Bias': 16,
#  'depthwise_conv2d_1': 17,
#  'conv2d_2/Kernel': 18,
#  'conv2d_2/Bias': 19,
#  'conv2d_2': 20,
#  'add_1': 21,
#  'p_re_lu_2/Alpha': 22,
#  'p_re_lu_2': 23,
#  'depthwise_conv2d_2/Kernel': 24,
#  'depthwise_conv2d_2/Bias': 25,
#  'depthwise_conv2d_2': 26,
#  'max_pooling2d': 27,
#  'conv2d_3/Kernel': 28,
#  'conv2d_3/Bias': 29,
#  'conv2d_3': 30,
#  'channel_padding/Paddings': 31,
#  'channel_padding': 32,
#  'add_2': 33,
#  'p_re_lu_3/Alpha': 34,
#  'p_re_lu_3': 35,
#  'depthwise_conv2d_3/Kernel': 36,
#  'depthwise_conv2d_3/Bias': 37,
#  'depthwise_conv2d_3': 38,
#  'conv2d_4/Kernel': 39,
#  'conv2d_4/Bias': 40,
#  'conv2d_4': 41,
#  'add_3': 42,
#  'p_re_lu_4/Alpha': 43,
#  'p_re_lu_4': 44,
#  'depthwise_conv2d_4/Kernel': 45,
#  'depthwise_conv2d_4/Bias': 46,
#  'depthwise_conv2d_4': 47,
#  'conv2d_5/Kernel': 48,
#  'conv2d_5/Bias': 49,
#  'conv2d_5': 50,
#  'add_4': 51,
#  'p_re_lu_5/Alpha': 52,
#  'p_re_lu_5': 53,
#  'depthwise_conv2d_5/Kernel': 54,
#  'depthwise_conv2d_5/Bias': 55,
#  'depthwise_conv2d_5': 56,
#  'max_pooling2d_1': 57,
#  'conv2d_6/Kernel': 58,
#  'conv2d_6/Bias': 59,
#  'conv2d_6': 60,
#  'channel_padding_1/Paddings': 61,
#  'channel_padding_1': 62,
#  'add_5': 63,
#  'p_re_lu_6/Alpha': 64,
#  'p_re_lu_6': 65,
#  'depthwise_conv2d_6/Kernel': 66,
#  'depthwise_conv2d_6/Bias': 67,
#  'depthwise_conv2d_6': 68,
#  'conv2d_7/Kernel': 69,
#  'conv2d_7/Bias': 70,
#  'conv2d_7': 71,
#  'add_6': 72,
#  'p_re_lu_7/Alpha': 73,
#  'p_re_lu_7': 74,
#  'depthwise_conv2d_7/Kernel': 75,
#  'depthwise_conv2d_7/Bias': 76,
#  'depthwise_conv2d_7': 77,
#  'conv2d_8/Kernel': 78,
#  'conv2d_8/Bias': 79,
#  'conv2d_8': 80,
#  'add_7': 81,
#  'p_re_lu_8/Alpha': 82,
#  'p_re_lu_8': 83,
#  'depthwise_conv2d_8/Kernel': 84,
#  'depthwise_conv2d_8/Bias': 85,
#  'depthwise_conv2d_8': 86,
#  'max_pooling2d_2': 87,
#  'conv2d_9/Kernel': 88,
#  'conv2d_9/Bias': 89,
#  'conv2d_9': 90,
#  'channel_padding_2/Paddings': 91,
#  'channel_padding_2': 92,
#  'add_8': 93,
#  'p_re_lu_9/Alpha': 94,
#  'p_re_lu_9': 95,
#  'depthwise_conv2d_9/Kernel': 96,
#  'depthwise_conv2d_9/Bias': 97,
#  'depthwise_conv2d_9': 98,
#  'conv2d_10/Kernel': 99,
#  'conv2d_10/Bias': 100,
#  'conv2d_10': 101,
#  'add_9': 102,
#  'p_re_lu_10/Alpha': 103,
#  'p_re_lu_10': 104,
#  'depthwise_conv2d_10/Kernel': 105,
#  'depthwise_conv2d_10/Bias': 106,
#  'depthwise_conv2d_10': 107,
#  'conv2d_11/Kernel': 108,
#  'conv2d_11/Bias': 109,
#  'conv2d_11': 110,
#  'add_10': 111,
#  'p_re_lu_11/Alpha': 112,
#  'p_re_lu_11': 113,
#  'depthwise_conv2d_11/Kernel': 114,
#  'depthwise_conv2d_11/Bias': 115,
#  'depthwise_conv2d_11': 116,
#  'conv2d_12/Kernel': 117,
#  'conv2d_12/Bias': 118,
#  'conv2d_12': 119,
#  'max_pooling2d_3': 120,
#  'add_11': 121,
#  'p_re_lu_12/Alpha': 122,
#  'p_re_lu_12': 123,
#  'depthwise_conv2d_12/Kernel': 124,
#  'depthwise_conv2d_12/Bias': 125,
#  'depthwise_conv2d_12': 126,
#  'conv2d_13/Kernel': 127,
#  'conv2d_13/Bias': 128,
#  'conv2d_13': 129,
#  'add_12': 130,
#  'p_re_lu_13/Alpha': 131,
#  'p_re_lu_13': 132,
#  'depthwise_conv2d_13/Kernel': 133,
#  'depthwise_conv2d_13/Bias': 134,
#  'depthwise_conv2d_13': 135,
#  'conv2d_14/Kernel': 136,
#  'conv2d_14/Bias': 137,
#  'conv2d_14': 138,
#  'add_13': 139,
#  'p_re_lu_14/Alpha': 140,
#  'p_re_lu_14': 141,
#  'depthwise_conv2d_14/Kernel': 142,
#  'depthwise_conv2d_14/Bias': 143,
#  'depthwise_conv2d_14': 144,
#  'conv2d_15/Kernel': 145,
#  'conv2d_15/Bias': 146,
#  'conv2d_15': 147,
#  'max_pooling2d_4': 148,
#  'add_14': 149,
#  'p_re_lu_15/Alpha': 150,
#  'p_re_lu_15': 151,
#  'depthwise_conv2d_15/Kernel': 152,
#  'depthwise_conv2d_15/Bias': 153,
#  'depthwise_conv2d_15': 154,
#  'conv2d_16/Kernel': 155,
#  'conv2d_16/Bias': 156,
#  'conv2d_16': 157,
#  'add_15': 158,
#  'p_re_lu_16/Alpha': 159,
#  'p_re_lu_16': 160,
#  'depthwise_conv2d_22/Kernel': 161,
#  'depthwise_conv2d_22/Bias': 162,
#  'depthwise_conv2d_22': 163,
#  'depthwise_conv2d_16/Kernel': 164,
#  'depthwise_conv2d_16/Bias': 165,
#  'depthwise_conv2d_16': 166,
#  'conv2d_27/Kernel': 167,
#  'conv2d_27/Bias': 168,
#  'conv2d_27': 169,
#  'conv2d_17/Kernel': 170,
#  'conv2d_17/Bias': 171,
#  'conv2d_17': 172,
#  'max_pooling2d_6': 173,
#  'add_22': 174,
#  'add_16': 175,
#  'p_re_lu_25/Alpha': 176,
#  'p_re_lu_25': 177,
#  'p_re_lu_17/Alpha': 178,
#  'p_re_lu_17': 179,
#  'conv2d_28/Kernel': 180,
#  'conv2d_28/Bias': 181,
#  'conv2d_28': 182,
#  'conv2d_18/Kernel': 183,
#  'conv2d_18/Bias': 184,
#  'conv2d_18': 185,
#  'p_re_lu_26/Alpha': 186,
#  'p_re_lu_26': 187,
#  'p_re_lu_18/Alpha': 188,
#  'p_re_lu_18': 189,
#  'depthwise_conv2d_23/Kernel': 190,
#  'depthwise_conv2d_23/Bias': 191,
#  'depthwise_conv2d_23': 192,
#  'depthwise_conv2d_17/Kernel': 193,
#  'depthwise_conv2d_17/Bias': 194,
#  'depthwise_conv2d_17': 195,
#  'conv2d_29/Kernel': 196,
#  'conv2d_29/Bias': 197,
#  'conv2d_29': 198,
#  'conv2d_19/Kernel': 199,
#  'conv2d_19/Bias': 200,
#  'conv2d_19': 201,
#  'add_23': 202,
#  'add_17': 203,
#  'p_re_lu_27/Alpha': 204,
#  'p_re_lu_27': 205,
#  'p_re_lu_19/Alpha': 206,
#  'p_re_lu_19': 207,
#  'conv2d_30/Kernel': 208,
#  'conv2d_30/Bias': 209,
#  'conv2d_30': 210,
#  'conv2d_20/Kernel': 211,
#  'conv2d_20/Bias': 212,
#  'conv2d_20': 213}

# %%
parameters = {}
for i in range(subgraph.TensorsLength()):
    tensor = subgraph.Tensors(i)
    if tensor.Buffer() > 0:
        name = tensor.Name().decode("utf8")
        parameters[name] = tensor.Buffer()

len(parameters)
# Out:
# 116

# %%
def get_weights(tensor_name):
    i = tensor_dict[tensor_name]
    tensor = subgraph.Tensors(i)
    buffer = tensor.Buffer()
    shape = get_shape(tensor)
#   assert(tensor.Type() == 0)  # FLOAT32
    
    W = model.Buffers(buffer).DataAsNumpy()
    W = W.view(dtype=np.float32)
    W = W.reshape(shape)
    return W

# %%
W = get_weights("conv2d/Kernel")
b = get_weights("conv2d/Bias")
W.shape, b.shape
# Out:
# ((16, 3, 3, 3), (16,))

# %%
import torch
from face_mesh import face_mesh

# %%
net = face_mesh()

# %%
net
# Out:
# face_mesh(
#   (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (backbone1): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): PReLU(num_parameters=16)
#     (2): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=16)
#     )
#     (3): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=16)
#     )
#     (4): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), groups=16)
#         (1): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=32)
#     )
#     (5): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#         (1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=32)
#     )
#     (6): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#         (1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=32)
#     )
#     (7): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), groups=32)
#         (1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=64)
#     )
#     (8): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=64)
#     )
#     (9): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=64)
#     )
#     (10): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), groups=64)
#         (1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=128)
#     )
#     (11): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=128)
#     )
#     (12): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=128)
#     )
#     (13): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), groups=128)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=128)
#     )
#     (14): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=128)
#     )
#     (15): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=128)
#     )
#   )
#   (backbone2): Sequential(
#     (0): BlazeBlock(
#       (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (convs): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), groups=128)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=128)
#     )
#     (1): BlazeBlock(
#       (convs): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#         (1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (act): PReLU(num_parameters=128)
#     )
#   )
#   (backbone3_0_0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=128)
#   (backbone2_2_0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128)
#   (backbone3_0_1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#   (backbone2_2_1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#   (backbone3_0_2): PReLU(num_parameters=128)
#   (backbone2_2_2): PReLU(num_parameters=128)
#   (backbone3_1_0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#   (backbone2_3_0): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#   (backbone3_1_1): PReLU(num_parameters=32)
#   (backbone2_3_1): PReLU(num_parameters=32)
#   (backbone3_2_0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#   (backbone2_4_0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32)
#   (backbone3_2_1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#   (backbone2_4_1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#   (backbone3_2_2): PReLU(num_parameters=32)
#   (backbone2_4_2): PReLU(num_parameters=32)
#   (backbone3_3): Conv2d(32, 1, kernel_size=(3, 3), stride=(3, 3))
#   (backbone2_5): Conv2d(32, 1404, kernel_size=(3, 3), stride=(3, 3))
# )

# %%
probable_names = []
for i in range(0, subgraph.TensorsLength()):
    tensor = subgraph.Tensors(i)
    if tensor.Buffer() > 0 and tensor.Type() == 0:
        probable_names.append(tensor.Name().decode("utf-8"))
        
probable_names[:5]
# Out:
# ['conv2d/Kernel',
#  'conv2d/Bias',
#  'p_re_lu/Alpha',
#  'depthwise_conv2d/Kernel',
#  'depthwise_conv2d/Bias']

# %%
convert = {}
i = 0
for name, params in net.state_dict().items():
    convert[name] = probable_names[i]
    i += 1

# %%
convert
# Out:
# {'backbone1.0.weight': 'conv2d/Kernel',
#  'backbone1.0.bias': 'conv2d/Bias',
#  'backbone1.1.weight': 'p_re_lu/Alpha',
#  'backbone1.2.convs.0.weight': 'depthwise_conv2d/Kernel',
#  'backbone1.2.convs.0.bias': 'depthwise_conv2d/Bias',
#  'backbone1.2.convs.1.weight': 'conv2d_1/Kernel',
#  'backbone1.2.convs.1.bias': 'conv2d_1/Bias',
#  'backbone1.2.act.weight': 'p_re_lu_1/Alpha',
#  'backbone1.3.convs.0.weight': 'depthwise_conv2d_1/Kernel',
#  'backbone1.3.convs.0.bias': 'depthwise_conv2d_1/Bias',
#  'backbone1.3.convs.1.weight': 'conv2d_2/Kernel',
#  'backbone1.3.convs.1.bias': 'conv2d_2/Bias',
#  'backbone1.3.act.weight': 'p_re_lu_2/Alpha',
#  'backbone1.4.convs.0.weight': 'depthwise_conv2d_2/Kernel',
#  'backbone1.4.convs.0.bias': 'depthwise_conv2d_2/Bias',
#  'backbone1.4.convs.1.weight': 'conv2d_3/Kernel',
#  'backbone1.4.convs.1.bias': 'conv2d_3/Bias',
#  'backbone1.4.act.weight': 'p_re_lu_3/Alpha',
#  'backbone1.5.convs.0.weight': 'depthwise_conv2d_3/Kernel',
#  'backbone1.5.convs.0.bias': 'depthwise_conv2d_3/Bias',
#  'backbone1.5.convs.1.weight': 'conv2d_4/Kernel',
#  'backbone1.5.convs.1.bias': 'conv2d_4/Bias',
#  'backbone1.5.act.weight': 'p_re_lu_4/Alpha',
#  'backbone1.6.convs.0.weight': 'depthwise_conv2d_4/Kernel',
#  'backbone1.6.convs.0.bias': 'depthwise_conv2d_4/Bias',
#  'backbone1.6.convs.1.weight': 'conv2d_5/Kernel',
#  'backbone1.6.convs.1.bias': 'conv2d_5/Bias',
#  'backbone1.6.act.weight': 'p_re_lu_5/Alpha',
#  'backbone1.7.convs.0.weight': 'depthwise_conv2d_5/Kernel',
#  'backbone1.7.convs.0.bias': 'depthwise_conv2d_5/Bias',
#  'backbone1.7.convs.1.weight': 'conv2d_6/Kernel',
#  'backbone1.7.convs.1.bias': 'conv2d_6/Bias',
#  'backbone1.7.act.weight': 'p_re_lu_6/Alpha',
#  'backbone1.8.convs.0.weight': 'depthwise_conv2d_6/Kernel',
#  'backbone1.8.convs.0.bias': 'depthwise_conv2d_6/Bias',
#  'backbone1.8.convs.1.weight': 'conv2d_7/Kernel',
#  'backbone1.8.convs.1.bias': 'conv2d_7/Bias',
#  'backbone1.8.act.weight': 'p_re_lu_7/Alpha',
#  'backbone1.9.convs.0.weight': 'depthwise_conv2d_7/Kernel',
#  'backbone1.9.convs.0.bias': 'depthwise_conv2d_7/Bias',
#  'backbone1.9.convs.1.weight': 'conv2d_8/Kernel',
#  'backbone1.9.convs.1.bias': 'conv2d_8/Bias',
#  'backbone1.9.act.weight': 'p_re_lu_8/Alpha',
#  'backbone1.10.convs.0.weight': 'depthwise_conv2d_8/Kernel',
#  'backbone1.10.convs.0.bias': 'depthwise_conv2d_8/Bias',
#  'backbone1.10.convs.1.weight': 'conv2d_9/Kernel',
#  'backbone1.10.convs.1.bias': 'conv2d_9/Bias',
#  'backbone1.10.act.weight': 'p_re_lu_9/Alpha',
#  'backbone1.11.convs.0.weight': 'depthwise_conv2d_9/Kernel',
#  'backbone1.11.convs.0.bias': 'depthwise_conv2d_9/Bias',
#  'backbone1.11.convs.1.weight': 'conv2d_10/Kernel',
#  'backbone1.11.convs.1.bias': 'conv2d_10/Bias',
#  'backbone1.11.act.weight': 'p_re_lu_10/Alpha',
#  'backbone1.12.convs.0.weight': 'depthwise_conv2d_10/Kernel',
#  'backbone1.12.convs.0.bias': 'depthwise_conv2d_10/Bias',
#  'backbone1.12.convs.1.weight': 'conv2d_11/Kernel',
#  'backbone1.12.convs.1.bias': 'conv2d_11/Bias',
#  'backbone1.12.act.weight': 'p_re_lu_11/Alpha',
#  'backbone1.13.convs.0.weight': 'depthwise_conv2d_11/Kernel',
#  'backbone1.13.convs.0.bias': 'depthwise_conv2d_11/Bias',
#  'backbone1.13.convs.1.weight': 'conv2d_12/Kernel',
#  'backbone1.13.convs.1.bias': 'conv2d_12/Bias',
#  'backbone1.13.act.weight': 'p_re_lu_12/Alpha',
#  'backbone1.14.convs.0.weight': 'depthwise_conv2d_12/Kernel',
#  'backbone1.14.convs.0.bias': 'depthwise_conv2d_12/Bias',
#  'backbone1.14.convs.1.weight': 'conv2d_13/Kernel',
#  'backbone1.14.convs.1.bias': 'conv2d_13/Bias',
#  'backbone1.14.act.weight': 'p_re_lu_13/Alpha',
#  'backbone1.15.convs.0.weight': 'depthwise_conv2d_13/Kernel',
#  'backbone1.15.convs.0.bias': 'depthwise_conv2d_13/Bias',
#  'backbone1.15.convs.1.weight': 'conv2d_14/Kernel',
#  'backbone1.15.convs.1.bias': 'conv2d_14/Bias',
#  'backbone1.15.act.weight': 'p_re_lu_14/Alpha',
#  'backbone2.0.convs.0.weight': 'depthwise_conv2d_14/Kernel',
#  'backbone2.0.convs.0.bias': 'depthwise_conv2d_14/Bias',
#  'backbone2.0.convs.1.weight': 'conv2d_15/Kernel',
#  'backbone2.0.convs.1.bias': 'conv2d_15/Bias',
#  'backbone2.0.act.weight': 'p_re_lu_15/Alpha',
#  'backbone2.1.convs.0.weight': 'depthwise_conv2d_15/Kernel',
#  'backbone2.1.convs.0.bias': 'depthwise_conv2d_15/Bias',
#  'backbone2.1.convs.1.weight': 'conv2d_16/Kernel',
#  'backbone2.1.convs.1.bias': 'conv2d_16/Bias',
#  'backbone2.1.act.weight': 'p_re_lu_16/Alpha',
#  'backbone3_0_0.weight': 'depthwise_conv2d_22/Kernel',
#  'backbone3_0_0.bias': 'depthwise_conv2d_22/Bias',
#  'backbone2_2_0.weight': 'depthwise_conv2d_16/Kernel',
#  'backbone2_2_0.bias': 'depthwise_conv2d_16/Bias',
#  'backbone3_0_1.weight': 'conv2d_27/Kernel',
#  'backbone3_0_1.bias': 'conv2d_27/Bias',
#  'backbone2_2_1.weight': 'conv2d_17/Kernel',
#  'backbone2_2_1.bias': 'conv2d_17/Bias',
#  'backbone3_0_2.weight': 'p_re_lu_25/Alpha',
#  'backbone2_2_2.weight': 'p_re_lu_17/Alpha',
#  'backbone3_1_0.weight': 'conv2d_28/Kernel',
#  'backbone3_1_0.bias': 'conv2d_28/Bias',
#  'backbone2_3_0.weight': 'conv2d_18/Kernel',
#  'backbone2_3_0.bias': 'conv2d_18/Bias',
#  'backbone3_1_1.weight': 'p_re_lu_26/Alpha',
#  'backbone2_3_1.weight': 'p_re_lu_18/Alpha',
#  'backbone3_2_0.weight': 'depthwise_conv2d_23/Kernel',
#  'backbone3_2_0.bias': 'depthwise_conv2d_23/Bias',
#  'backbone2_4_0.weight': 'depthwise_conv2d_17/Kernel',
#  'backbone2_4_0.bias': 'depthwise_conv2d_17/Bias',
#  'backbone3_2_1.weight': 'conv2d_29/Kernel',
#  'backbone3_2_1.bias': 'conv2d_29/Bias',
#  'backbone2_4_1.weight': 'conv2d_19/Kernel',
#  'backbone2_4_1.bias': 'conv2d_19/Bias',
#  'backbone3_2_2.weight': 'p_re_lu_27/Alpha',
#  'backbone2_4_2.weight': 'p_re_lu_19/Alpha',
#  'backbone3_3.weight': 'conv2d_30/Kernel',
#  'backbone3_3.bias': 'conv2d_30/Bias',
#  'backbone2_5.weight': 'conv2d_20/Kernel',
#  'backbone2_5.bias': 'conv2d_20/Bias'}

# %%
new_state_dict = OrderedDict()

for dst, src in convert.items():
    W = get_weights(src)
    print(dst, src, W.shape, net.state_dict()[dst].shape)
    
    if W.ndim == 4:
        if W.shape[0] == 1 and src!= 'conv2d_30/Kernel':
            W = W.transpose((3, 0, 1, 2))  # depthwise conv
        else:
            W = W.transpose((0, 3, 1, 2))  # regular conv
    if W.ndim == 3:
        W = W.reshape(W.shape[2])  #PReLU
        
    new_state_dict[dst] = torch.from_numpy(W)
    # handflag.weight conv_handflag/Kernel (1, 2, 2, 192) torch.Size([1, 192, 2, 2])
# Out:
# backbone1.0.weight conv2d/Kernel (16, 3, 3, 3) torch.Size([16, 3, 3, 3])
# backbone1.0.bias conv2d/Bias (16,) torch.Size([16])
# backbone1.1.weight p_re_lu/Alpha (1, 1, 16) torch.Size([16])
# backbone1.2.convs.0.weight depthwise_conv2d/Kernel (1, 3, 3, 16) torch.Size([16, 1, 3, 3])
# backbone1.2.convs.0.bias depthwise_conv2d/Bias (16,) torch.Size([16])
# backbone1.2.convs.1.weight conv2d_1/Kernel (16, 1, 1, 16) torch.Size([16, 16, 1, 1])
# backbone1.2.convs.1.bias conv2d_1/Bias (16,) torch.Size([16])
# backbone1.2.act.weight p_re_lu_1/Alpha (1, 1, 16) torch.Size([16])
# backbone1.3.convs.0.weight depthwise_conv2d_1/Kernel (1, 3, 3, 16) torch.Size([16, 1, 3, 3])
# backbone1.3.convs.0.bias depthwise_conv2d_1/Bias (16,) torch.Size([16])
# backbone1.3.convs.1.weight conv2d_2/Kernel (16, 1, 1, 16) torch.Size([16, 16, 1, 1])
# backbone1.3.convs.1.bias conv2d_2/Bias (16,) torch.Size([16])
# backbone1.3.act.weight p_re_lu_2/Alpha (1, 1, 16) torch.Size([16])
# backbone1.4.convs.0.weight depthwise_conv2d_2/Kernel (1, 3, 3, 16) torch.Size([16, 1, 3, 3])
# backbone1.4.convs.0.bias depthwise_conv2d_2/Bias (16,) torch.Size([16])
# backbone1.4.convs.1.weight conv2d_3/Kernel (32, 1, 1, 16) torch.Size([32, 16, 1, 1])
# backbone1.4.convs.1.bias conv2d_3/Bias (32,) torch.Size([32])
# backbone1.4.act.weight p_re_lu_3/Alpha (1, 1, 32) torch.Size([32])
# backbone1.5.convs.0.weight depthwise_conv2d_3/Kernel (1, 3, 3, 32) torch.Size([32, 1, 3, 3])
# backbone1.5.convs.0.bias depthwise_conv2d_3/Bias (32,) torch.Size([32])
# backbone1.5.convs.1.weight conv2d_4/Kernel (32, 1, 1, 32) torch.Size([32, 32, 1, 1])
# backbone1.5.convs.1.bias conv2d_4/Bias (32,) torch.Size([32])
# backbone1.5.act.weight p_re_lu_4/Alpha (1, 1, 32) torch.Size([32])
# backbone1.6.convs.0.weight depthwise_conv2d_4/Kernel (1, 3, 3, 32) torch.Size([32, 1, 3, 3])
# backbone1.6.convs.0.bias depthwise_conv2d_4/Bias (32,) torch.Size([32])
# backbone1.6.convs.1.weight conv2d_5/Kernel (32, 1, 1, 32) torch.Size([32, 32, 1, 1])
# backbone1.6.convs.1.bias conv2d_5/Bias (32,) torch.Size([32])
# backbone1.6.act.weight p_re_lu_5/Alpha (1, 1, 32) torch.Size([32])
# backbone1.7.convs.0.weight depthwise_conv2d_5/Kernel (1, 3, 3, 32) torch.Size([32, 1, 3, 3])
# backbone1.7.convs.0.bias depthwise_conv2d_5/Bias (32,) torch.Size([32])
# backbone1.7.convs.1.weight conv2d_6/Kernel (64, 1, 1, 32) torch.Size([64, 32, 1, 1])
# backbone1.7.convs.1.bias conv2d_6/Bias (64,) torch.Size([64])
# backbone1.7.act.weight p_re_lu_6/Alpha (1, 1, 64) torch.Size([64])
# backbone1.8.convs.0.weight depthwise_conv2d_6/Kernel (1, 3, 3, 64) torch.Size([64, 1, 3, 3])
# backbone1.8.convs.0.bias depthwise_conv2d_6/Bias (64,) torch.Size([64])
# backbone1.8.convs.1.weight conv2d_7/Kernel (64, 1, 1, 64) torch.Size([64, 64, 1, 1])
# backbone1.8.convs.1.bias conv2d_7/Bias (64,) torch.Size([64])
# backbone1.8.act.weight p_re_lu_7/Alpha (1, 1, 64) torch.Size([64])
# backbone1.9.convs.0.weight depthwise_conv2d_7/Kernel (1, 3, 3, 64) torch.Size([64, 1, 3, 3])
# backbone1.9.convs.0.bias depthwise_conv2d_7/Bias (64,) torch.Size([64])
# backbone1.9.convs.1.weight conv2d_8/Kernel (64, 1, 1, 64) torch.Size([64, 64, 1, 1])
# backbone1.9.convs.1.bias conv2d_8/Bias (64,) torch.Size([64])
# backbone1.9.act.weight p_re_lu_8/Alpha (1, 1, 64) torch.Size([64])
# backbone1.10.convs.0.weight depthwise_conv2d_8/Kernel (1, 3, 3, 64) torch.Size([64, 1, 3, 3])
# backbone1.10.convs.0.bias depthwise_conv2d_8/Bias (64,) torch.Size([64])
# backbone1.10.convs.1.weight conv2d_9/Kernel (128, 1, 1, 64) torch.Size([128, 64, 1, 1])
# backbone1.10.convs.1.bias conv2d_9/Bias (128,) torch.Size([128])
# backbone1.10.act.weight p_re_lu_9/Alpha (1, 1, 128) torch.Size([128])
# backbone1.11.convs.0.weight depthwise_conv2d_9/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone1.11.convs.0.bias depthwise_conv2d_9/Bias (128,) torch.Size([128])
# backbone1.11.convs.1.weight conv2d_10/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone1.11.convs.1.bias conv2d_10/Bias (128,) torch.Size([128])
# backbone1.11.act.weight p_re_lu_10/Alpha (1, 1, 128) torch.Size([128])
# backbone1.12.convs.0.weight depthwise_conv2d_10/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone1.12.convs.0.bias depthwise_conv2d_10/Bias (128,) torch.Size([128])
# backbone1.12.convs.1.weight conv2d_11/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone1.12.convs.1.bias conv2d_11/Bias (128,) torch.Size([128])
# backbone1.12.act.weight p_re_lu_11/Alpha (1, 1, 128) torch.Size([128])
# backbone1.13.convs.0.weight depthwise_conv2d_11/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone1.13.convs.0.bias depthwise_conv2d_11/Bias (128,) torch.Size([128])
# backbone1.13.convs.1.weight conv2d_12/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone1.13.convs.1.bias conv2d_12/Bias (128,) torch.Size([128])
# backbone1.13.act.weight p_re_lu_12/Alpha (1, 1, 128) torch.Size([128])
# backbone1.14.convs.0.weight depthwise_conv2d_12/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone1.14.convs.0.bias depthwise_conv2d_12/Bias (128,) torch.Size([128])
# backbone1.14.convs.1.weight conv2d_13/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone1.14.convs.1.bias conv2d_13/Bias (128,) torch.Size([128])
# backbone1.14.act.weight p_re_lu_13/Alpha (1, 1, 128) torch.Size([128])
# backbone1.15.convs.0.weight depthwise_conv2d_13/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone1.15.convs.0.bias depthwise_conv2d_13/Bias (128,) torch.Size([128])
# backbone1.15.convs.1.weight conv2d_14/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone1.15.convs.1.bias conv2d_14/Bias (128,) torch.Size([128])
# backbone1.15.act.weight p_re_lu_14/Alpha (1, 1, 128) torch.Size([128])
# backbone2.0.convs.0.weight depthwise_conv2d_14/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone2.0.convs.0.bias depthwise_conv2d_14/Bias (128,) torch.Size([128])
# backbone2.0.convs.1.weight conv2d_15/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone2.0.convs.1.bias conv2d_15/Bias (128,) torch.Size([128])
# backbone2.0.act.weight p_re_lu_15/Alpha (1, 1, 128) torch.Size([128])
# backbone2.1.convs.0.weight depthwise_conv2d_15/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone2.1.convs.0.bias depthwise_conv2d_15/Bias (128,) torch.Size([128])
# backbone2.1.convs.1.weight conv2d_16/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone2.1.convs.1.bias conv2d_16/Bias (128,) torch.Size([128])
# backbone2.1.act.weight p_re_lu_16/Alpha (1, 1, 128) torch.Size([128])
# backbone3_0_0.weight depthwise_conv2d_22/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone3_0_0.bias depthwise_conv2d_22/Bias (128,) torch.Size([128])
# backbone2_2_0.weight depthwise_conv2d_16/Kernel (1, 3, 3, 128) torch.Size([128, 1, 3, 3])
# backbone2_2_0.bias depthwise_conv2d_16/Bias (128,) torch.Size([128])
# backbone3_0_1.weight conv2d_27/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone3_0_1.bias conv2d_27/Bias (128,) torch.Size([128])
# backbone2_2_1.weight conv2d_17/Kernel (128, 1, 1, 128) torch.Size([128, 128, 1, 1])
# backbone2_2_1.bias conv2d_17/Bias (128,) torch.Size([128])
# backbone3_0_2.weight p_re_lu_25/Alpha (1, 1, 128) torch.Size([128])
# backbone2_2_2.weight p_re_lu_17/Alpha (1, 1, 128) torch.Size([128])
# backbone3_1_0.weight conv2d_28/Kernel (32, 1, 1, 128) torch.Size([32, 128, 1, 1])
# backbone3_1_0.bias conv2d_28/Bias (32,) torch.Size([32])
# backbone2_3_0.weight conv2d_18/Kernel (32, 1, 1, 128) torch.Size([32, 128, 1, 1])
# backbone2_3_0.bias conv2d_18/Bias (32,) torch.Size([32])
# backbone3_1_1.weight p_re_lu_26/Alpha (1, 1, 32) torch.Size([32])
# backbone2_3_1.weight p_re_lu_18/Alpha (1, 1, 32) torch.Size([32])
# backbone3_2_0.weight depthwise_conv2d_23/Kernel (1, 3, 3, 32) torch.Size([32, 1, 3, 3])
# backbone3_2_0.bias depthwise_conv2d_23/Bias (32,) torch.Size([32])
# backbone2_4_0.weight depthwise_conv2d_17/Kernel (1, 3, 3, 32) torch.Size([32, 1, 3, 3])
# backbone2_4_0.bias depthwise_conv2d_17/Bias (32,) torch.Size([32])
# backbone3_2_1.weight conv2d_29/Kernel (32, 1, 1, 32) torch.Size([32, 32, 1, 1])
# backbone3_2_1.bias conv2d_29/Bias (32,) torch.Size([32])
# backbone2_4_1.weight conv2d_19/Kernel (32, 1, 1, 32) torch.Size([32, 32, 1, 1])
# backbone2_4_1.bias conv2d_19/Bias (32,) torch.Size([32])
# backbone3_2_2.weight p_re_lu_27/Alpha (1, 1, 32) torch.Size([32])
# backbone2_4_2.weight p_re_lu_19/Alpha (1, 1, 32) torch.Size([32])
# backbone3_3.weight conv2d_30/Kernel (1, 3, 3, 32) torch.Size([1, 32, 3, 3])
# backbone3_3.bias conv2d_30/Bias (1,) torch.Size([1])
# backbone2_5.weight conv2d_20/Kernel (1404, 3, 3, 32) torch.Size([1404, 32, 3, 3])
# backbone2_5.bias conv2d_20/Bias (1404,) torch.Size([1404])
# /root/miniconda3/envs/blazeface/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   from ipykernel import kernelapp as app

# %%
net.load_state_dict(new_state_dict, strict=True)
# Out:
# <All keys matched successfully>

# %%
torch.save(net.state_dict(), "face_mesh.pth")
